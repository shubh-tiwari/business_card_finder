# %%
import sys
sys.path.append('../')
from business_card_finder import Finder

# %%
finder = Finder()

# %%
name = 'Chris'
print("Find image with name : ", name)
imgfile, _, _ = finder.find_business_card(name, plot=True)
# Out:
# Find image with name :  Chris

# %%
name = 'Bnard'
print("Find image with name : ", name)
imgfile, _, _ = finder.find_business_card(name, plot=True)
# Out:
# Find image with name :  Bnard

# %%
name = 'MAR'
print("Find image with name : ", name)
imgfile, _, _ = finder.find_business_card(name, plot=True)
# Out:
# Find image with name :  MAR

# %%
name = 'Rafal'
print("Find image with name : ", name)
imgfile, _, _ = finder.find_business_card(name, plot=True)
# Out:
# Find image with name :  Rafal
